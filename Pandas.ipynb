# %%
import pandas as pd

# %%
ourdata =pd.read_csv('/content/price.csv')
ourdata
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200   61000
# 3  3600   68000
# 4  4000  725000

# %%
ourdata.sum()
# Out:
# area       16400
# price    1969000
# dtype: int64

# %%
ourdata['area']
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %% [markdown]
# # Pandas 2nd Class

# %%
mydata = pd.read_csv('/content/Member Details.csv')

# %%
mydata
# Out:
#         Name  ID Campus
# 0  Anjan Das  20    CoU
# 1  Shahjalal  26    CoU
# 2      Sajon   5   RUET
# 3     Tousif   4    CoU

# %%
mydata.head()
# Out:
#         Name  ID Campus
# 0  Anjan Das  20    CoU
# 1  Shahjalal  26    CoU
# 2      Sajon   5   RUET
# 3     Tousif   4    CoU

# %%
mydata.head(2)
# Out:
#         Name  ID Campus
# 0  Anjan Das  20    CoU
# 1  Shahjalal  26    CoU

# %%
mydata.tail(2)
# Out:
#      Name  ID Campus
# 2   Sajon   5   RUET
# 3  Tousif   4    CoU

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   ID      4 non-null      int64
#  2   Campus  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
# Statistics of data
mydata.describe()
# Out:
#               ID
# count   4.000000
# mean   13.750000
# std    10.965856
# min     4.000000
# 25%     4.750000
# 50%    12.500000
# 75%    21.500000
# max    26.000000

# %% [markdown]
# # Building Blocks: Series and Dataframe

# %% [markdown]
# Series

# %%
import numpy as np

# %%
ages = np.array([13, 25, 19])
series1  = pd.Series(ages)
series1
# Out:
# 0    13
# 1    25
# 2    19
# dtype: int64

# %%
series2 = pd.Series(ages, index = ["Anjan","Tousif", "Sajon"])
series2
# Out:
# Anjan     13
# Tousif    25
# Sajon     19
# dtype: int64

# %% [markdown]
# # **Dataframe**

# %%
dataf = pd.DataFrame([
    ['Sajon', 99, 'RUET'],
    ['Tousif', 9, 'CoU'],
    ['Anjan', 7, 'CoU']
],

columns = ['Name', 'Age', 'Campus'])



dataf
# Out:
#      Name  Age Campus
# 0   Sajon   99   RUET
# 1  Tousif    9    CoU
# 2   Anjan    7    CoU

# %%
dataf.set_index('Name')
# Out:
#         Age Campus
# Name
# Sajon    99   RUET
# Tousif    9    CoU
# Anjan     7    CoU

# %%
dataf.to_csv('Output.csv')

# %% [markdown]
# # Object Creation in Pandas

# %%
s = pd.Series([1,2,3, np.nan, 6, 7,8])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    6.0
# 5    7.0
# 6    8.0
# dtype: float64

# %%
dates = pd.date_range('20240302', periods=14)
dates
# Out:
# DatetimeIndex(['2024-03-02', '2024-03-03', '2024-03-04', '2024-03-05',
#                '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
# date = pd.date_range(start='24/03/03', end= '24/04/03')
date = pd.date_range(start='03/03/24', end= '03/07/24', freq= 'M')
date
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame({
    'A':1.0,
    'B':pd.Timestamp('20240303'),
    'C':np.array([3]*4, dtype='int32'),
    'D': pd.Categorical(['train', 'test', 'train','test']),
    'F': 'foo'
})
df
# Out:
#      A          B  C      D    F
# 0  1.0 2024-03-03  3  train  foo
# 1  1.0 2024-03-03  3   test  foo
# 2  1.0 2024-03-03  3  train  foo
# 3  1.0 2024-03-03  3   test  foo

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
plt.close("Hello")

# %%
data = pd.Series(abs(np.random.randn(30)*1000), index=pd.date_range('1/1/24', periods=30))
data
# Out:
# 2024-01-01     783.459893
# 2024-01-02     380.942719
# 2024-01-03     618.432394
# 2024-01-04    1264.045514
# 2024-01-05     344.179085
# 2024-01-06     294.431780
# 2024-01-07    1254.902638
# 2024-01-08     882.410161
# 2024-01-09    1786.365646
# 2024-01-10     445.623202
# 2024-01-11     946.768710
# 2024-01-12     336.069823
# 2024-01-13     303.429405
# 2024-01-14    1781.179598
# 2024-01-15     488.943276
# 2024-01-16    1023.648992
# 2024-01-17     751.287788
# 2024-01-18     413.353874
# 2024-01-19    1134.054758
# 2024-01-20     972.220029
# 2024-01-21     219.003767
# 2024-01-22     835.936589
# 2024-01-23     902.074435
# 2024-01-24     206.846504
# 2024-01-25    1300.828532
# 2024-01-26    2776.217272
# 2024-01-27     919.162092
# 2024-01-28     104.679055
# 2024-01-29    1374.977839
# 2024-01-30     294.350359
# Freq: D, dtype: float64

# %%
data.dtype
# Out:
# dtype('float64')

# %%
data.describe()
# Out:
# count      30.000000
# mean      837.994191
# std       586.743158
# min       104.679055
# 25%       353.369994
# 50%       809.698241
# 75%      1106.453316
# max      2776.217272
# dtype: float64

# %%
data.plot()
# Out:
# <Axes: >
